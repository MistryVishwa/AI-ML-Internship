# %% [markdown]
# # Data Exploration Notebook
#
# This notebook demonstrates professional formatting, structured analysis, and proper code commenting practices.
#
# ## 1. Import Libraries
# First, we will import all the necessary libraries required for our data manipulation and visualization tasks.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style for professional plots
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 2. Load Data
# Here we load the data. For demonstration purposes, we will create a dummy dataset.

# %%
# Define sample data in a dictionary
data_dict = {
    'Age': [25, 30, 35, 40, 45, 50, 55],
    'Income': [40000, 55000, 70000, 85000, 100000, 115000, 130000],
    'Score': [88, 92, 85, 75, 95, 80, 89]
}

# Convert the dictionary into a pandas DataFrame
df = pd.DataFrame(data_dict)

# Display the first few rows of the dataset
df.head()

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)
# We will now perform some basic statistical analysis and visualize the relationship between variables.

# %%
# Calculate basic descriptive statistics for numerical columns
summary_stats = df.describe()
print("Summary Statistics:")
print(summary_stats)

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Variables')
plt.show()
